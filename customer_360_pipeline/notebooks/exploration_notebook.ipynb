# %%
from pyspark.sql import SparkSession
import pandas as pd
import random
from datetime import datetime
from datetime import timedelta

# %%
# -------------------------
# run the cell in order to clean the source volumes
# -------------------------
volumes = [
    "/Volumes/customer_360/customer_360_source/source_customer_volume",
    "/Volumes/customer_360/customer_360_source/source_product_volume",
    "/Volumes/customer_360/customer_360_source/source_sales_volume"
]

# Delete all CSVs in each volume
for vol in volumes:
    dbutils.fs.rm(vol, recurse=True)  # deletes all files and subfolders
    dbutils.fs.mkdirs(vol)            # recreate empty folder
    print(f"✅ Cleared all files in {vol}")

# %%
# %sql
select * from delta.`/Volumes/customer_360/customer_360_bronze/bronze_customer_volume`;

# %%
# %sql
select * from delta.`/Volumes/customer_360/customer_360_bronze/bronze_product_volume`;

# %%
# %sql
select * from delta.`/Volumes/customer_360/customer_360_bronze/bronze_sales_volume`;

# %%
# %sql
select * from delta.`/Volumes/customer_360/customer_360_silver/silver_customer_volume`;

# %%
# %sql
select * from delta.`/Volumes/customer_360/customer_360_silver/silver_product_volume`;

# %%
# %sql
select * from delta.`/Volumes/customer_360/customer_360_silver/silver_sales_volume`;

# %%
# %sql
select * from delta.`/Volumes/customer_360/customer_360_gold/gold_customer_dim_volume`;

# %%
# %sql
select * from delta.`/Volumes/customer_360/customer_360_gold/gold_product_dim_volume`;

# %%
# %sql
select * from delta.`/Volumes/customer_360/customer_360_gold/gold_sales_fact_volume`;

# %%
# %sql
select * from delta.`/Volumes/customer_360/audit/audit_volume/etl_audit/` order by layer;

# %%
# %sql
select *,from_utc_timestamp(load_time, 'Asia/Kolkata') AS load_time_ist from delta.`/Volumes/customer_360/audit/audit_volume/etl_audit/` order by load_time_ist;
