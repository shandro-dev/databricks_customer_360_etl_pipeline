# %% [markdown]
# Optimize all SILVER table and add indexing on dedicated columns.

# %%
# %sql
OPTIMIZE delta.`/Volumes/customer_360/customer_360_silver/silver_customer_volume` ZORDER BY (customer_id, country);
OPTIMIZE delta.`/Volumes/customer_360/customer_360_silver/silver_product_volume` ZORDER BY (product_id);
OPTIMIZE delta.`/Volumes/customer_360/customer_360_silver/silver_sales_volume` ZORDER BY (order_date, customer_id, product_id);

# %% [markdown]
# Delete older files and by default keep last 15 days for time travel.

# %%
# %sql
VACUUM delta.`/Volumes/customer_360/customer_360_silver/silver_customer_volume` RETAIN 360 HOURS;
VACUUM delta.`/Volumes/customer_360/customer_360_silver/silver_product_volume` RETAIN 360 HOURS;
VACUUM delta.`/Volumes/customer_360/customer_360_silver/silver_sales_volume` RETAIN 360 HOURS;
