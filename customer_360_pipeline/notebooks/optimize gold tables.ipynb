# %% [markdown]
# Optimize all GOLD table and add indexing on dedicated columns.

# %%
# %sql
OPTIMIZE delta.`/Volumes/customer_360/customer_360_gold/gold_customer_dim_volume` ZORDER BY (customer_id, country);
OPTIMIZE delta.`/Volumes/customer_360/customer_360_gold/gold_product_dim_volume` ZORDER BY (product_id);
OPTIMIZE delta.`/Volumes/customer_360/customer_360_gold/gold_sales_fact_volume` ZORDER BY (order_date, customer_id, product_id);

# %% [markdown]
# Delete older files and by default keep last 15 days for time travel.

# %%
# %sql
VACUUM delta.`/Volumes/customer_360/customer_360_gold/gold_customer_dim_volume` RETAIN 360 HOURS;
VACUUM delta.`/Volumes/customer_360/customer_360_gold/gold_product_dim_volume` RETAIN 360 HOURS;
VACUUM delta.`/Volumes/customer_360/customer_360_gold/gold_sales_fact_volume` RETAIN 360 HOURS;

# %%
from pyspark.sql import SparkSession

# %%
spark=SparkSession.builder.appName("audit").getOrCreate()
df_audit=spark.read\
    .format("delta")\
    .load("/Volumes/customer_360/audit/audit_volume/etl_audit")
